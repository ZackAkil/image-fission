# %%
# %matplotlib inline
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image, ImageFilter
from resizeimage import resizeimage

# %%
from skimage import data
import random

# %%
from scipy import ndimage, misc

# %%
test_image = data.chelsea()
plt.imshow(test_image)
plt.grid(False)

# %%
def mut_brightness(img, amount):
    int_img = test_image.astype(int)
    mut_img = int_img + amount
    clip_img = mut_img.clip(0, 255)
    return clip_img.astype(np.uint8)

# %%
plt.imshow(mut_brightness(test_image, 150))

# %%
def mut_crop(img, width, height, x, y):
    return img[y:y+height, x:x+width]
    
def rand_mut_crop(img, width, height):
    rand_x = random.randint(0,test_image.shape[1]-width)
    rand_y = random.randint(0,test_image.shape[0]-height)
    return mut_crop(img, width, height, rand_x, rand_y)

# %%
plt.imshow(mut_crop(test_image, 100,200,100,100))

# %%
test_image.shape
# Out:
# (300, 451, 3)

# %%
plt.imshow(rand_mut_crop(test_image, 100, 300))

# %%
plt.imshow(misc.imresize(misc.imresize(test_image, (50,50) ),(400,400)) )

# %%
def mut_zoom(img, zoom):
    zoomed_size = [int(d*zoom) for d in img.shape[:2]]
    return misc.imresize(img, zoomed_size)

def mut_pixelate(img, zoom):
    shrink = mut_zoom(img, zoom)
    return misc.imresize(shrink, img.shape[:2])

# %%
plt.imshow(mut_zoom(test_image,0.2))

# %%
plt.imshow(mut_pixelate(test_image,0.1))
